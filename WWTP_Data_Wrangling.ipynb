# %%
# Importing the important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Loading the data
df1=pd.read_csv('1--01-10.06.20..csv')
df2=pd.read_csv('2--01.01.18-10.01.18..csv')
df3=pd.read_csv('3--01.01.19-10.01.19..csv')
df4=pd.read_csv('4--01.02-26.01.20..csv')
df5=pd.read_csv('5--01.02.18-10.02.18..csv')
df6=pd.read_csv('6--01.02.19-10.02.19..csv')
df7=pd.read_csv('7--01.03-23.02.20..csv')
df8=pd.read_csv('8--01.03.18-10.03.18..csv')
df9=pd.read_csv('9--01.04-07.04.20..csv')
df10=pd.read_csv('10--01.04.18-10.04.18..csv')
df11=pd.read_csv('11--01.04.19-10.04.19..csv')
df12=pd.read_csv('12--01.10.18-10.10.18..csv')
df13=pd.read_csv('13--01.10.19-10.10.19..csv')
df14=pd.read_csv('14--01.11.18-10.11.18..csv')
df15=pd.read_csv('15--01.12.18-10.12.18..csv')
df16=pd.read_csv('16--01.12.19-08.12.19..csv')
df17=pd.read_csv('17--03.11.19-17.11.19..csv')
df18=pd.read_csv('18--5-17.05.20..csv')
df19=pd.read_csv('19--07.03-01.03.20..csv')
df20=pd.read_csv('20--07.04-13.04.20..csv')
df21=pd.read_csv('21--08.02-02.02.20..csv')
df22=pd.read_csv('22--08.12.19-15.12.19..csv')
df23=pd.read_csv('23--10.01.18-20.01.18..csv')
df24=pd.read_csv('24--10.01.19-20.01.19..csv')
df25=pd.read_csv('25--10.02.18-20.02.18..csv')
df26=pd.read_csv('26--10.02.19-20.02.19..csv')
df27=pd.read_csv('27--10.03.18-20.03.18..csv')
df28=pd.read_csv('28--10.03.19-20.03.19..csv')
df29=pd.read_csv('29--10.04.18-20.04.18..csv')
df30=pd.read_csv('30--10.04.19-20.04.19..csv')
df31=pd.read_csv('31--10.10.18-20.10.18..csv')
df32=pd.read_csv('32--10.10.19-20.10.19..csv')
df33=pd.read_csv('33--10.11.17-20.11.17..csv')
df34=pd.read_csv('34--10.11.18-20.11.18..csv')
df35=pd.read_csv('35--10.12.18-20.12.18..csv')
df36=pd.read_csv('36--12.01-05.01.20..csv')
df37=pd.read_csv('37--13.04-25.04.20..csv')
df38=pd.read_csv('38--14.03-08.03.20..csv')
df39=pd.read_csv('39--15.02-09.02.20..csv')
df40=pd.read_csv('40--15.03-21.03.20..csv')
df41=pd.read_csv('41--15.12.19-22.12.19..csv')
df42=pd.read_csv('42--17.11.19-01.12.19..csv')
df43=pd.read_csv('43--18-31.05.20..csv')
df44=pd.read_csv('44--19.01-12.01.20..csv')
df45=pd.read_csv('45--20.01.18-01.02.18..csv')
df46=pd.read_csv('46--20.01.18-31.01.18..csv')
df47=pd.read_csv('47--20.02.18-01.03.18..csv')
df48=pd.read_csv('48--20.03.18-01.04.18..csv')
df49=pd.read_csv('49--20.03.19-01.04.19..csv')
df50=pd.read_csv('50--20.04.18-01.05.18..csv')
df51=pd.read_csv('51--20.04.19-01.05.19..csv')
df52=pd.read_csv('52--20.10.18-31.10.18..csv')
df53=pd.read_csv('53--20.10.19-03.11.19..csv')
df54=pd.read_csv('54--20.11.17-01.12.17..csv')
df55=pd.read_csv('55--20.11.18-30.11.18..csv')
df56=pd.read_csv('56--20.12.17-31.12.17..csv')
df57=pd.read_csv('57--20.12.18-31.12.18..csv')
df58=pd.read_csv('58--22.02-16.02.20..csv')
df59=pd.read_csv('59--22.03-31.03.20..csv')
df60=pd.read_csv('60--22.12.19-29.12.19..csv')
df61=pd.read_csv('61--25.04-05.05.20..csv')
df62=pd.read_csv('62--26.01-19.01.20..csv')
df63=pd.read_csv('63--28.02.19-10.03.19..csv')
df64=pd.read_csv('64--29.12.19-05.01.20..csv')
df65=pd.read_csv('65--30.11.18..csv')
df66=pd.read_csv('66--31.01.18..csv')
df67=pd.read_csv('67--31.10.18..csv')
df68=pd.read_csv('68--31.12.18..csv')

# %%
# Concating all the data files
dfn=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,
             df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36,df37,df38,
             df39,df40,df41,df42,df43,df44,df45,df46,df47,df48,df49,df50,df51,df52,df53,df54,df55,df56,
              df57,df58,df59,df60,df61,df62,df63,df64,df65,df66,df67,df68], axis=0)
# Displaying all the columns
pd.set_option('display.max_columns', len(dfn.columns))
dfn.head(2)
# Out:
#                   Time  C1 - Energy - RE1\r\nKWH  C2 - Energy - RE1\r\nKWH  \
# 0  2020-06-01 00:00:04                       NaN                       NaN
# 1  2020-06-01 00:00:43                     671.0                     789.0
#
#    D1 - Energy - RE2\r\nKWH  D2 - Energy - RE2\r\nKWH  \
# 0                       NaN                       NaN
# 1                     689.0                     961.0
#
#    F1 - Energy - RE3\r\nKWH  F2 - Energy - RE3\r\nKWH  \
# 0                       NaN                       NaN
# 1                   915.307                   762.663
#
#    G1 - Energy - RE4\r\nKWH  G2 - Energy - RE4\r\nKWH  DO - RE1\r\nmg/L  \
# 0                       NaN                       NaN               NaN
# 1                    925.26                       NaN               0.4
#
#    DO outlet - RE1\r\nmg/L  Rotors working - RE1\r\n  \
# 0                      NaN                       NaN
# 1                    2.026                       NaN
#
# ...

# %%
# Shuffling the data
dfn.sample(frac = 0.5, replace = True)
dfn.head()
# Out:
#                   Time  C1 - Energy - RE1\r\nKWH  C2 - Energy - RE1\r\nKWH  \
# 0  2020-06-01 00:00:04                       NaN                       NaN
# 1  2020-06-01 00:00:43                     671.0                     789.0
# 2  2020-06-01 00:01:43                     660.0                     778.0
# 3  2020-06-01 00:02:43                     678.0                     782.0
# 4  2020-06-01 00:03:43                     656.0                     780.0
#
#    D1 - Energy - RE2\r\nKWH  D2 - Energy - RE2\r\nKWH  \
# 0                       NaN                       NaN
# 1                     689.0                     961.0
# 2                     682.0                     963.0
# 3                     691.0                     956.0
# 4                     687.0                     966.0
#
#    F1 - Energy - RE3\r\nKWH  F2 - Energy - RE3\r\nKWH  \
# 0                       NaN                       NaN
# 1                   915.307                   762.663
# ...

# %%
# number of rows and columns in the data
dfn.shape
# Out:
# (881828, 85)

# %% [markdown]
# #### There are 881,825 rows and 85 columns in the data.

# %%
# Getting info about the data
dfn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 881828 entries, 0 to 1440
# Data columns (total 85 columns):
#  #   Column                                          Non-Null Count   Dtype
# ---  ------                                          --------------   -----
#  0   Time                                            881828 non-null  object
#  1   C1 - Energy - RE1
# KWH                          540409 non-null  float64
#  2   C2 - Energy - RE1
# KWH                          550781 non-null  float64
#  3   D1 - Energy - RE2
# KWH                          669496 non-null  float64
#  4   D2 - Energy - RE2
# KWH                          631506 non-null  float64
#  5   F1 - Energy - RE3
# KWH                          655055 non-null  float64
#  6   F2 - Energy - RE3
# KWH                          571419 non-null  float64
#  7   G1 - Energy - RE4
# KWH                          572937 non-null  float64
#  8   G2 - Energy - RE4
# KWH                          598576 non-null  float64
# ...

# %% [markdown]
# #### There are 84 columns of float type and 1 column of object type

# %%
# Getting more description of the data
dfn.describe()
# Out:
#        C1 - Energy - RE1\r\nKWH  C2 - Energy - RE1\r\nKWH  \
# count             540409.000000             550781.000000
# mean                 577.600419                705.598577
# std                  263.623150                279.065298
# min                   -1.000000                  0.000000
# 25%                  402.000000                574.000000
# 50%                  520.000000                693.000000
# 75%                  696.000000                769.000000
# max                 2148.000000               2329.000000
#
#        D1 - Energy - RE2\r\nKWH  D2 - Energy - RE2\r\nKWH  \
# count             669496.000000             631506.000000
# mean                 657.815599                725.953662
# std                  172.544522                209.698000
# min                  -57.000000                  0.000000
# 25%                  560.000000                591.000000
# 50%                  675.000000                792.000000
# ...

# %% [markdown]
# It is clear from the above findings that there are some columns that are more significant than others. I will make a new dataframe having columns which are assumed to have more impact on the outcome. The rest of the columns will not be taken into consiferation this time

# %%
# Making the dataframe of the columns that are important
df = pd.DataFrame(zip(dfn['C1 - Energy - RE1\r\nKWH'],dfn['DO - RE1\r\nmg/L'],dfn['DO outlet - RE1\r\nmg/L'],dfn['Rotors depth level - RE1\r\ncm'],dfn['Turbidity - Stage A\r\nNTU'],dfn['Outlet temperature - Stage A\r\nמע"צ'],dfn['''Mlss temperature - Stage A\r\nמע"צ'''],dfn['RAS TSS - Stage B\r\ngr/L'],dfn['Stage B WAS - D station\r\nm3/hr'],dfn['Feed Flow to Reactor1\r\nm3/hr'],dfn['Raw sewage Conductivity\r\nmg/L'],dfn['Raw sewage Tss\r\nmg/L'],dfn['pH - Stage B\r\n'],dfn['B11 flow meter\r\nm3/hr'],dfn['Ammonia - Stage B\r\nmg/L'],dfn['Nitrate Concentration - RE1\r\nmg/L']),columns = ['reactor_energy','dissolved_oxygen','dissolved_oxygen_outlet','rotors_depth_level','turbidity','outlet_temp','reactor_temp','ras_tss','was_station','feedflow_to_reactor','raw_sewage_conductivity','raw_sewage_tss','pH','b11_flowmeter','ammonia_outlet_conc','nitrate_outlet_conc'])

# %%
# Checking the new data
df.head()
# Out:
#    reactor_energy  dissolved_oxygen  dissolved_oxygen_outlet  \
# 0             NaN               NaN                      NaN
# 1           671.0             0.400                    2.026
# 2           660.0             0.405                      NaN
# 3           678.0               NaN                      NaN
# 4           656.0             0.366                    2.025
#
#    rotors_depth_level  turbidity  outlet_temp  reactor_temp  ras_tss  \
# 0                 NaN        NaN          NaN           NaN      NaN
# 1                 NaN      1.944       26.313        25.270   10.693
# 2              28.240      1.812       26.312        25.267   10.562
# 3              27.726      1.758       26.310        25.265   10.756
# 4              27.751      1.856       26.309        25.263   10.759
#
#    was_station  feedflow_to_reactor  raw_sewage_conductivity  raw_sewage_tss  \
# 0          NaN                  NaN                      NaN             NaN
# ...

# %%
# More discription about the data
df.describe()
# Out:
#        reactor_energy  dissolved_oxygen  dissolved_oxygen_outlet  \
# count   540409.000000     602424.000000            487193.000000
# mean       577.600419          0.608991                 0.617119
# std        263.623150          0.415568                 0.643228
# min         -1.000000          0.000000                 0.000000
# 25%        402.000000          0.325000                 0.151000
# 50%        520.000000          0.569000                 0.366000
# 75%        696.000000          0.830000                 0.865000
# max       2148.000000          9.897000                 6.762000
#
#        rotors_depth_level      turbidity    outlet_temp   reactor_temp  \
# count       738512.000000  784906.000000  614089.000000  701769.000000
# mean            27.004684       2.685088      23.598968      22.205126
# std              2.022593       1.228608       2.584912       3.122409
# min            -50.122000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# From the above description, it is clear that there are lots of missing values in the dataset. I will fill the missing values with median value of that respective column.

# %%
# Filling the missing values of the column with 'median' value of the respective column
df['reactor_energy'].fillna(df['reactor_energy'].median(),inplace=True)
df['dissolved_oxygen'].fillna(df['dissolved_oxygen'].median(),inplace=True)
df['dissolved_oxygen_outlet'].fillna(df['dissolved_oxygen_outlet'].median(),inplace=True)
df['rotors_depth_level'].fillna(df['rotors_depth_level'].median(),inplace=True)
df['turbidity'].fillna(df['turbidity'].median(),inplace=True)
df['outlet_temp'].fillna(df['outlet_temp'].median(),inplace=True)
df['reactor_temp'].fillna(df['reactor_temp'].median(),inplace=True)
df['ras_tss'].fillna(df['ras_tss'].median(),inplace=True)
df['was_station'].fillna(df['was_station'].median(),inplace=True)
df['feedflow_to_reactor'].fillna(df['feedflow_to_reactor'].median(),inplace=True)
df['raw_sewage_conductivity'].fillna(df['raw_sewage_conductivity'].median(),inplace=True)
df['raw_sewage_tss'].fillna(df['raw_sewage_tss'].median(),inplace=True)
df['pH'].fillna(df['pH'].median(),inplace=True)
df['b11_flowmeter'].fillna(df['b11_flowmeter'].median(),inplace=True)
df['ammonia_outlet_conc'].fillna(df['ammonia_outlet_conc'].median(),inplace=True)
df['nitrate_outlet_conc'].fillna(df['nitrate_outlet_conc'].median(),inplace=True)

# %%
# Checking the data description
df.describe()
# Out:
#        reactor_energy  dissolved_oxygen  dissolved_oxygen_outlet  \
# count   881828.000000     881828.000000            881828.000000
# mean       555.299157          0.596320                 0.504739
# std        208.271466          0.343984                 0.494142
# min         -1.000000          0.000000                 0.000000
# 25%        482.000000          0.437000                 0.308000
# 50%        520.000000          0.569000                 0.366000
# 75%        560.000000          0.698000                 0.433000
# max       2148.000000          9.897000                 6.762000
#
#        rotors_depth_level      turbidity    outlet_temp   reactor_temp  \
# count       881828.000000  881828.000000  881828.000000  881828.000000
# mean            27.125977       2.671889      23.507588      22.148949
# std              1.871319       1.159733       2.161530       2.787654
# min            -50.122000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# There are some negative values for many columns in the dataset which seems to be erroneous. As there are very few number of such cases. The negative valus in the dataset will be removed.

# %%
# Checking the number of rows with negative reactor_energy
len(df[df['reactor_energy']<=0])
# Out:
# 19

# %%
# Removing the rows with values less than '0' in their respective columns and getting the description of the data
df = df[(df[['reactor_energy']]>0).all(axis = 1)]
df = df[(df[['dissolved_oxygen']]>0).all(axis = 1)]
df = df[(df[['dissolved_oxygen_outlet']]>0).all(axis = 1)]
df = df[(df[['rotors_depth_level']]>0).all(axis = 1)]
df = df[(df[['turbidity']]>0).all(axis = 1)]
df = df[(df[['outlet_temp']]>0).all(axis = 1)]
df = df[(df[['reactor_temp']]>0).all(axis = 1)]
df = df[(df[['ras_tss']]>0).all(axis = 1)]
df = df[(df[['was_station']]>0).all(axis = 1)]
df = df[(df[['feedflow_to_reactor']]>0).all(axis = 1)]
df = df[(df[['raw_sewage_conductivity']]>0).all(axis = 1)]
df = df[(df[['raw_sewage_tss']]>0).all(axis = 1)]
df = df[(df[['pH']]>0).all(axis = 1)]
df = df[(df[['b11_flowmeter']]>0).all(axis = 1)]
df = df[(df[['ammonia_outlet_conc']]>0).all(axis = 1)]
df = df[(df[['nitrate_outlet_conc']]>0).all(axis = 1)]



df.describe()
# Out:
#        reactor_energy  dissolved_oxygen  dissolved_oxygen_outlet  \
# count   877464.000000     877464.000000            877464.000000
# mean       555.578670          0.597022                 0.505089
# std        208.417514          0.343736                 0.494418
# min          2.000000          0.002000                 0.001000
# 25%        483.000000          0.437000                 0.309000
# 50%        520.000000          0.569000                 0.366000
# 75%        561.000000          0.698000                 0.433000
# max       2148.000000          9.897000                 6.762000
#
#        rotors_depth_level      turbidity    outlet_temp   reactor_temp  \
# count       877464.000000  877464.000000  877464.000000  877464.000000
# mean            27.130749       2.673526      23.502143      22.141372
# std              1.819929       1.159555       2.155305       2.782296
# min             15.892000       0.190000      17.313000      13.411000
# ...

# %%
# Cheking the number of rows and number of columns in the dataset after dropping negative values
df.shape
# Out:
# (877464, 16)

# %%
# Plotting the histogram plot for all numeric and boolean columns
df.hist(figsize = (20, 20), bins = 20)
plt.tight_layout()

# %% [markdown]
# It is clear that the values are distributed over a wide range in almost all columns. It need to be addressed as values are not normally distibuted. Some columns have left skewed  distribution while others have right skewed distribution.

# %%
# Checking the correlation and plotting the coorealtion heatmap
df_corr = df.corr()
fig,ax = plt.subplots(figsize=(20,10))
ax = sns.heatmap(df_corr, annot=True,linewidth = 0.5,fmt='.2f', cmap='Blues')

# %% [markdown]
# From the coorelation heatmap, it is evident that ammonia_outlet_conc depends on various factors like reactor_energy, dissolved_oxygen, dissolved_oxygen_outlet, rotors_depth_level, feedflow_to_reactor, was_station and rss_tss. Whereas, nitrate_outlet_concentration depends on dissolved_oxygen, was_station.

# %%
df.to_csv('./data/data_wrangling.csv', index = False)
